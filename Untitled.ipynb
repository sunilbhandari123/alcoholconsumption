# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import opendatasets as od

# %%
datasets='https://www.kaggle.com/datasets/uciml/student-alcohol-consumption/data'

# %%
od.download(datasets)
# Out:
# Skipping, found downloaded files in ".\student-alcohol-consumption" (use force=True to force download)

# %%
import os

# %%
data_dir='.\\student-alcohol-consumption'

# %%
os.listdir(data_dir)
# Out:
# ['student-mat.csv', 'student-merge.R', 'student-por.csv']

# %%
data_maths=pd.read_csv("student-alcohol-consumption\student-mat.csv")
data_pogues=pd.read_csv("student-alcohol-consumption\student-por.csv")

# %% [markdown]
# Here we will consider only the student who are enrolled in math

# %%
data_maths.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data_maths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %% [markdown]
# Here majority of the data are categorical.

# %%
df=data_maths.copy()

# %%
df.describe(include='all')
# Out:
#        school  sex         age address famsize Pstatus        Medu  \
# count     395  395  395.000000     395     395     395  395.000000
# unique      2    2         NaN       2       2       2         NaN
# top        GP    F         NaN       U     GT3       T         NaN
# freq      349  208         NaN     307     281     354         NaN
# mean      NaN  NaN   16.696203     NaN     NaN     NaN    2.749367
# std       NaN  NaN    1.276043     NaN     NaN     NaN    1.094735
# min       NaN  NaN   15.000000     NaN     NaN     NaN    0.000000
# 25%       NaN  NaN   16.000000     NaN     NaN     NaN    2.000000
# 50%       NaN  NaN   17.000000     NaN     NaN     NaN    3.000000
# 75%       NaN  NaN   18.000000     NaN     NaN     NaN    4.000000
# max       NaN  NaN   22.000000     NaN     NaN     NaN    4.000000
#
#               Fedu   Mjob   Fjob  ...      famrel    freetime       goout  \
# count   395.000000    395    395  ...  395.000000  395.000000  395.000000
# ...

# %% [markdown]
# Observations:
# 1.)Maximum value is greater than mean and median that means there is presence of outliers.
# 2.)Since count value is same for all features so there are no missing values.

# %%
#lets see the counts of the student in school
df['school'].value_counts()
# Out:
# GP    349
# MS     46
# Name: school, dtype: int64

# %%
# Here most of the students are from/enrolled in Gabriel Pereira  school.

# %%
plt.figure(figsize=(8,6))
sns.countplot(x="sex",data=df)
plt.xlabel('Gender',fontsize=17)
plt.ylabel('Count',fontsize=17)
plt.show()

# %%
#Female students are slightly higher than that of male ones.

# %%
sns.countplot(x='age',data=df)
plt.xlabel('Age',fontsize=17)
plt.ylabel('Count',fontsize=17)
plt.show()

# %%
# majority students are of age 15-18 years.

# %%
sns.countplot(x='address',data=df)
plt.xlabel('Address',fontsize=17)
plt.ylabel('Count',fontsize=17)
plt.show()

# %%
# form above we can see that most of the students are from urban area rather than rular area.

# %%
sns.countplot(x='famsize',data=df)
plt.xlabel('FamilySize',fontsize=17)
plt.ylabel('Count',fontsize=17)
plt.show()

# %%
#most of the students family have greater than 3 members

# %%
sns.countplot(x='Pstatus',data=df)
plt.xlabel('FamilyType',fontsize=17)
plt.ylabel('Count',fontsize=17)
plt.show()

# %%
#There are only few students whose parents are seperated

# %%
sns.countplot(x='Medu',data=df)
plt.xlabel('Mothers Education',fontsize=17)
plt.ylabel('Count',fontsize=17)
plt.show()

# %%
#Its seems like it is diverse.and there are very few students whose mothers have none education background.

# %%
sns.countplot(x='Fedu',data=df)
plt.xlabel('Fathers education',fontsize=17)
plt.ylabel("Count",fontsize=17)
plt.show()

# %%
# Fathers educations are also diverse and are very few fathers whose education is none.

# %%
sns.countplot(x='Mjob',data=df)
plt.xlabel('Mothers Job',fontsize=17)
plt.ylabel('Counts',fontsize=17)
plt.show()

# %%
#fews students mothers will be at home as house wife and other students have some jobs as they will not be
# at home as there students will be at at there free time.

# %%
sns.countplot(x='Fjob',data=df)
plt.xlabel('Fathers Education',fontsize=17)
plt.ylabel('Count',fontsize=17)
plt.show()

# %%
sns.countplot(x='failures',data=df)
plt.xlabel('Failuers in Years',fontsize=17)
plt.ylabel('Count',fontsize=17)
plt.show()

# %%
#There are few student who failed in pervious years

# %%
sns.countplot(x='freetime',data=df)
plt.xlabel('Free Time',fontsize=17)
plt.ylabel('Count',fontsize=17)
plt.show()

# %%
# most of the students have pretty much free time after school so they have high chances to get into addictions.

# %%
sns.countplot(x='goout',data=df)
plt.xlabel('Going Out with Friends',fontsize=14)
plt.ylabel("Count",fontsize=17)
plt.show()

# %%
# pretty good number of students likes to go out with there friends where they can consume alcohol.

# %%
sns.countplot(x='Dalc',data=df)
plt.xlabel('Workday Alcohol Consumptions',fontsize=14)
plt.ylabel("Count",fontsize=17)
plt.show()

# %%
df['Dalc'].value_counts(normalize=True)
# Out:
# 1    0.698734
# 2    0.189873
# 3    0.065823
# 5    0.022785
# 4    0.022785
# Name: Dalc, dtype: float64

# %%
#Very few amount of students consume the alcohol in working day of the week and 69 percent of the student
#consumes very low alcohol or no alcohol

# %%
sns.countplot(x='Walc',data=df)
plt.xlabel('Weekend Alcohol Consumptions',fontsize=14)
plt.ylabel("Count",fontsize=17)
plt.show()

# %%
df['Walc'].value_counts(normalize=True)
# Out:
# 1    0.382278
# 2    0.215190
# 3    0.202532
# 4    0.129114
# 5    0.070886
# Name: Walc, dtype: float64

# %%
# In weekend alcohol consumption of the students increases pretty much as compared to workday ie no alcohol 
#decreases from 69 percent to 38 percent.

# %%
sns.histplot(df['absences'],bins=40)
plt.xlabel('Absences of the Students',fontsize=14)
plt.ylabel("Count",fontsize=17)
plt.show()

# %%
#here most of the students have very less absent but some students have pretty much high absences.

# %% [markdown]
# Lets see the Dependent variables

# %%
sns.histplot(df['G1'],bins=30,discrete=True)
plt.xlabel('First Period Grade',fontsize=14)
plt.ylabel("Count",fontsize=17)
plt.show()

# %%
#it seems like normal distribution

# %%
sns.histplot(df['G2'],discrete=True)
plt.xlabel('Second Period Grade',fontsize=14)
plt.ylabel("Count",fontsize=17)
plt.show()

# %%
# it is also like normal distribution but have outliers

# %%
sns.histplot(df['G3'],bins=30,discrete=True)
plt.xlabel('Final Period Grade',fontsize=14)
plt.ylabel("Count",fontsize=17)
plt.show()

# %%
# it is also like normal distribution but have outliers

# %% [markdown]
# In First period grade there are no 0 grade but in second and Final period grade there are 0 grades that means there
# might be students who has given first period exam but not others otherwise it might be missing values or
# the student might dropped out.

# %% [markdown]
# Now leets see how our feature affect the alcohol consumption in workday as well as in weekends

# %%
sns.countplot(x='Dalc',hue='sex',data=df)
plt.xlabel('Workday Alcohol Consumption',fontsize=14)
plt.ylabel('Count',fontsize=17)
plt.show()

# %%
# it is clear that male consume termendous amount of alcohol than that of female in workdays.

# %%
sns.countplot(x='Walc',hue='sex',data=df)
plt.xlabel('Weekend Alcohol Consumption',fontsize=14)
plt.ylabel('Count',fontsize=17)
plt.show()

# %%
# it is clear that male consume termendous amount of alcohol than that of female in weekends also.

# %%
plt.figure(figsize=(14,8))
sns.countplot(x='age',hue='Dalc',data=df)
plt.xlabel('Workday Alcohol Consumption',fontsize=14)
plt.ylabel('Count',fontsize=17)
plt.show()

# %%
#Its seems lai teenegers consumers consume a lot of alcohol than that of higher age group.

# %%
plt.figure(figsize=(14,8))
sns.countplot(x='age',hue='Walc',data=df)
plt.xlabel('Weekend Alcohol Consumption',fontsize=14)
plt.ylabel('Count',fontsize=17)
plt.show()

# %%
#in weekend also teenegers students consumes lot of alcohol than other groups.

# %%
plt.figure(figsize=(14,8))
sns.countplot(x='address',hue='Dalc',data=df)
plt.xlabel('Workday Alcohol Consumption',fontsize=14)
plt.ylabel('Count',fontsize=17)
plt.show()

# %%
plt.figure(figsize=(14,8))
sns.countplot(x='address',hue='Walc',data=df)
plt.xlabel('Weekend Alcohol Consumption',fontsize=14)
plt.ylabel('Count',fontsize=17)
plt.show()

# %%
#we cannot determine this by using this because student from rular areas are very few it will affect

# %%
for group, data in df.groupby('address'):
    data['Dalc'].hist(alpha=0.5, density=True, label=group, grid=False)
plt.legend()
plt.title('Workday alcohol consumption vs living area')
plt.show()

# %%
for group ,data in df.groupby('address'):
    data['Walc'].hist(alpha=0.5,density=True,label=group,grid=False)
plt.legend()
plt.title('Weekend alcohol consumption vs living area')
plt.show()

# %%
sns.barplot(data=df,x='address',y='Walc')
# Out:
# <AxesSubplot:xlabel='address', ylabel='Walc'>

# %%
sns.barplot(data=df,x='address',y='Dalc')
# Out:
# <AxesSubplot:xlabel='address', ylabel='Dalc'>

# %%
#from here we can say that students  from rular area consumes more amount of alcohol

# %% [markdown]
# parent's cohabitation status might also be the important factor so that student consumes alcohol as single
# parents/parents apart it is littel difficult to take care of childern as compared to parents living together

# %%
for group,data in df.groupby('Pstatus'):
    data['Walc'].hist(alpha=0.5,density=True,label=group,grid=False)
plt.legend()
plt.title('Parents Status vs Weekend alcohol consumption')
plt.show()

# %%
for group,data in df.groupby('Pstatus'):
    data['Dalc'].hist(alpha=0.5,density=True,label=group,grid=False)
plt.legend()
plt.title('Parents Status vs Workday alcohol consumption')
plt.show()

# %%
# it seems like students whose parents are apart they are addicated to alcohol abit more.

# %%
for group, data in df.groupby('freetime'):
    data['Walc'].hist(alpha=0.5,density=True,label=group,grid=False)
plt.legend()
plt.title('FreeTime vs Workday Alcohol consumption')
plt.show()

# %%
#As freetime increases the consumption of alcohol also increases.

# %% [markdown]
# Leets see what feature will effect our Dependendent Variable We will see with some important feature no all.

# %%
#Lets see for first period grade one

# %% [markdown]
# Lets see for the Gender what gender is performing well in results is male getting more grade than females
# vice verca

# %%
sns.kdeplot(data=df,x='G1',hue='sex')
plt.title('Effect of gender in Result')
plt.show()

# %% [markdown]
# Here we can see male have slightly good result than that of the female ones but we cannot be 100% sure for
# surity we have to perform T test with significance level of 0.05

# %%
from scipy.stats import ttest_ind
from scipy import stats as st

# %%
st.ttest_ind(df.query('sex=="M"')['G1'],df.query('sex=="F"')['G1']).pvalue
# Out:
# 0.06825227168840965

# %% [markdown]
# since it is greater than 0.05 we cannot reject the null hypothesis Therefore there is not enough statistical evidence to conclude that there is a significant difference in grades between male and female students based on the t test .

# %% [markdown]
# LETS SEE THE ALCOHOL CONSUMPTION NOW FIRSTLY WORKDAY

# %%
plt.figure(figsize=(16,8))
for Dalc,data in df.groupby('Dalc'):
    sns.kdeplot(data['G1'],label=Dalc)
plt.legend()
plt.title('Effect of workday alcohol consumption in Grades')
plt.show()

# %%
df.groupby('Dalc')['G1'].mean().plot( kind='bar')
plt.show()

# %% [markdown]
# Mean of student who doesnot consumes less alcholol is more than than that of consuming ones and the
# students who doesnot consumes alcohol there peak is fatter where as students who consumes alcohol there
# peak is narrow and high so by these we cannot say any thing so for the conformation we have to perform
# t test with significance level of 0.05.since 1 has more mean we will compare it with other to perform ttest.

# %%
print(st.ttest_ind(df.query('Dalc==1')['G1'],df.query('Dalc==2')['G1']).pvalue)
print(st.ttest_ind(df.query('Dalc==1')['G1'],df.query('Dalc==3')['G1']).pvalue)
print(st.ttest_ind(df.query('Dalc==1')['G1'],df.query('Dalc==4')['G1']).pvalue)
print(st.ttest_ind(df.query('Dalc==1')['G1'],df.query('Dalc==5')['G1']).pvalue)
# Out:
# 0.0549661581608816
# 0.4067394438297568
# 0.2364718248068344
# 0.5412776029332933

# %% [markdown]
# Here firstly the 1 and 2 have less value than that of signifiance level that means we can assume that the
# lower the alcohol consumption higher the grades or vice-verca

# %% [markdown]
# LETS SEE FOR THE WEEKDAYS

# %%
plt.figure(figsize=(16,8))
for Walc,data in df.groupby('Walc'):
    sns.kdeplot(data['G1'],label=Walc)
plt.title('Effect of Weekdays Alcohol Consumption vs Grades')
plt.legend()
plt.show()

# %%
df.groupby('Walc')['G1'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Walc'>

# %% [markdown]
# Thoes students whose mean is higher they have flat peak and so we are unable to say any thing so now lets
# conform by t test.

# %%
print(st.ttest_ind(df.query('Walc==2')['G1'],df.query('Walc==1')['G1']).pvalue)
print(st.ttest_ind(df.query('Walc==2')['G1'],df.query('Walc==3')['G1']).pvalue)
print(st.ttest_ind(df.query('Walc==2')['G1'],df.query('Walc==4')['G1']).pvalue)
print(st.ttest_ind(df.query('Walc==2')['G1'],df.query('Walc==5')['G1']).pvalue)
# Out:
# 0.8436820215347033
# 0.5163030967029885
# 0.021015082558925764
# 0.06975746607041089

# %% [markdown]
# here low or no consumption in weekends has no effect in grades where as high consumption of alcohol in
# weekends have less grades.

# %%
sns.kdeplot(data=df,x='G1',hue=pd.cut(df['age'], bins=5))
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(16,8))
for age,data in df.groupby('age'):
    if age <20: ## above this age the number of values are very less.
        sns.kdeplot(data['G1'],label=age)
plt.title('Grade base on Age')
plt.legend()
plt.show()

# %% [markdown]
# Here we can see that the distribution of the grade doesnot changes to much we can use t test to conform it
# taking the signifiance level at 0.05 we will compare 15 with others because form its distribution it is
# that it has more data ie mean.

# %%
print(st.ttest_ind(df.query('age==15')['G1'],df.query('age==16')['G1']).pvalue)
print(st.ttest_ind(df.query('age==15')['G1'],df.query('age==17')['G1']).pvalue)
print(st.ttest_ind(df.query('age==15')['G1'],df.query('age==18')['G1']).pvalue)
print(st.ttest_ind(df.query('age==15')['G1'],df.query('age==19')['G1']).pvalue)
# Out:
# 0.551222679293337
# 0.49663330651812754
# 0.3430797659206085
# 0.20286169615705926

# %% [markdown]
# This is way more higher that our signifance leve this concludes that there is no effect of Age in grades of
# the students.
